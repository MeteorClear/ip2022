# %%
x,y='a',1
for (x, y) in [('a',1), ('b',2), ('c',3), ('d',4)]:
    print(x)

for x in range(5):
    print(x)
# Out:
# a
# b
# c
# d
# 0
# 1
# 2
# 3
# 4

# %%
g = [('a',1), ('b',2), ('c',3), ('d',4)]
for (i, item) in enumerate(g):
    print(i,item)
# Out:
# 0 ('a', 1)
# 1 ('b', 2)
# 2 ('c', 3)
# 3 ('d', 4)
