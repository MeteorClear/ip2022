# %%
def myfun(x, y):
    return x * y
myfun(3, 4)
# Out:
# 12

# %%
def apply(q, x):
    return q(x)
def myfun2(x):
    return x*3

apply(myfun2, 7)
# Out:
# 21

# %%
apply(lambda z: z * 4, 7)
# Out:
# 28

# %%
def myfun3(b, c=3, d="hello"):
    return b + c

myfun3(5,3,"hello")
# Out:
# 8

# %%
x='abc'
y=34
"%s xyz %d" % (x,y)
# Out:
# 'abc xyz 34'

# %%
";".join( ["abc", "def", "ghi"] )
# Out:
# 'abc;def;ghi'

# %%
for e in [1,2]:
    print(e)
s = [1,2]
it = iter(s)
next(it)
# Out:
# 1
# 2
# 1
