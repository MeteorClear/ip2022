# %%
d={'user':'bozo', 'pswd':1234}
d
d['user']='clown'
d
d['id']=45
d
# Out:
# {'user': 'clown', 'pswd': 1234, 'id': 45}

# %%
del d['user']
d
# Out:
# {'pswd': 1234, 'id': 45}

# %%
d.clear()
d
# Out:
# {}

# %%
a=[1,2]
del a[1]
a
# Out:
# [1]

# %%
d={'user':'bozo', 'pswd':1234, 'i':35}
d.keys()
d.values()
d.items()
# Out:
# dict_items([('user', 'bozo'), ('pswd', 1234), ('i', 35)])
